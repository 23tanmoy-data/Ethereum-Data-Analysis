# %% [markdown]
# ### Ethereum Historical Dataset Analysis By Python

# %% [markdown]
# ##### Dataset :- https://www.kaggle.com/datasets/prasoonkottarathil/ethereum-historical-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
from datetime import datetime

# %%
df2=pd.read_csv('H:/ETH_2.csv')
df2.head(5).style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_6288d_row0_col0, #T_6288d_row2_col3, #T_6288d_row3_col4, #T_6288d_row3_col5, #T_6288d_row3_col6, #T_6288d_row3_col7, #T_6288d_row4_col5 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6288d_row0_col3, #T_6288d_row0_col4, #T_6288d_row0_col5, #T_6288d_row0_col6, #T_6288d_row1_col3, #T_6288d_row1_col4, #T_6288d_row1_col7, #T_6288d_row2_col7, #T_6288d_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_6288d_row0_col7 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_6288d_row1_col0 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_6288d_row1_col5, #T_6288d_row2_col5 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_6288d_row1_col6, #T_6288d_row2_col6 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_6288d_row2_col0 {
#   background-color: #80c066;
#   color: #000000;
# }
# #T_6288d_row2_col4, #T_6288d_row4_col6 {
#   background-color: #e2f066;
#   color: #000000;
# }
# ...

# %%
df3=pd.read_csv('H:/ETH_3.csv')
df3.head(5).style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_ce5ac_row0_col2, #T_ce5ac_row0_col5, #T_ce5ac_row1_col5 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_ce5ac_row0_col3, #T_ce5ac_row0_col6, #T_ce5ac_row0_col7, #T_ce5ac_row1_col2, #T_ce5ac_row2_col4, #T_ce5ac_row2_col5 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ce5ac_row0_col4, #T_ce5ac_row1_col6, #T_ce5ac_row1_col7, #T_ce5ac_row3_col2, #T_ce5ac_row3_col3, #T_ce5ac_row4_col5 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ce5ac_row1_col3 {
#   background-color: #86c266;
#   color: #000000;
# }
# #T_ce5ac_row1_col4 {
#   background-color: #a9d466;
#   color: #000000;
# }
# #T_ce5ac_row2_col2, #T_ce5ac_row3_col5 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_ce5ac_row2_col3 {
#   background-color: #229066;
#   color: #f1f1f1;
# }
# #T_ce5ac_row2_col6 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_ce5ac_row2_col7 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# ...

# %%
df2.describe().round(2)
# Out:
#        Unix Timestamp        Open        High         Low       Close  \
# count    1.984012e+06  1984012.00  1984012.00  1984012.00  1984012.00
# mean     6.154583e+11      241.82      241.96      241.68      241.82
# std      7.621617e+11      241.52      241.71      241.31      241.52
# min      1.462801e+09        0.00        5.99        0.00        5.99
# 25%      1.492561e+09       50.07       50.09       50.06       50.07
# 50%      1.522321e+09      183.32      183.37      183.26      183.32
# 75%      1.554502e+12      301.01      301.14      300.93      301.01
# max      1.586995e+12     1420.00     1420.01     1419.89     1420.00
#
#            Volume
# count  1984012.00
# mean        26.12
# std        444.46
# min          0.00
# 25%          0.00
# 50%          0.00
# 75%          7.13
# max     276423.54

# %%
df3.describe().round(2)
# Out:
#           Open     High      Low    Close  Volume ETH    Volume USD
# count  1438.00  1438.00  1438.00  1438.00     1438.00  1.438000e+03
# mean    239.40   248.92   227.68   239.47    37206.38  1.139557e+07
# std     237.66   248.68   222.79   237.61    69083.36  2.143780e+07
# min       6.77     7.29     5.99     6.77        0.00  0.000000e+00
# 25%      79.78    84.88    74.68    80.73     7020.22  7.541171e+05
# 50%     181.43   187.02   175.85   181.43    17804.39  3.221372e+06
# 75%     297.74   306.02   287.43   297.50    42044.51  1.204918e+07
# max    1381.85  1420.01  1270.00  1381.85  1827755.14  2.221193e+08

# %%
df1.shape
# Out:
# (34497, 8)

# %%
df2.shape
# Out:
# (1984012, 8)

# %%
df3.shape
# Out:
# (1438, 8)

# %%
df1
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  Year Month          Day
# ...

# %%
df1=pd.read_csv('H:/ETH_1.csv')
df1.head(5).style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_3c1ba_row0_col0, #T_3c1ba_row1_col7, #T_3c1ba_row3_col3, #T_3c1ba_row3_col4, #T_3c1ba_row3_col5, #T_3c1ba_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3c1ba_row0_col3, #T_3c1ba_row0_col4, #T_3c1ba_row0_col5, #T_3c1ba_row0_col6, #T_3c1ba_row3_col7, #T_3c1ba_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_3c1ba_row0_col7 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_3c1ba_row1_col0 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_3c1ba_row1_col3 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_3c1ba_row1_col4 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_3c1ba_row1_col5 {
#   background-color: #259266;
#   color: #f1f1f1;
# }
# #T_3c1ba_row1_col6 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_3c1ba_row2_col0 {
#   background-color: #80c066;
#   color: #000000;
# }
# #T_3c1ba_row2_col3 {
#   background-color: #d4ea66;
# ...

# %% [markdown]
# ##### Spliting the date column for simplify the analysis for date , month and year basis for each Database ETHEREUM BITCOIN

# %%
df1[['Year','Month','Day']] = df1['Date'].str.split('-',expand=True)

# %%
df1
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  Year Month          Day
# ...

# %%
df1[['Date','Time']] = df1['Day'].str.split(' ',expand=True)
df1
# Out:
#        Unix Timestamp Date  Symbol    Open    High     Low   Close  \
# 0       1586995200000   16  ETHUSD  152.94  152.94  150.39  150.39
# 1       1586991600000   15  ETHUSD  155.81  155.81  151.39  152.94
# 2       1586988000000   15  ETHUSD  157.18  157.30  155.32  155.81
# 3       1586984400000   15  ETHUSD  158.04  158.31  157.16  157.18
# 4       1586980800000   15  ETHUSD  157.10  158.10  156.87  158.04
# ...               ...  ...     ...     ...     ...     ...     ...
# 34492      1462813200   09  ETHUSD    9.83    9.83    9.48    9.49
# 34493      1462809600   09  ETHUSD    9.99    9.99    9.79    9.83
# 34494      1462806000   09  ETHUSD   10.00   10.00    9.99    9.99
# 34495      1462802400   09  ETHUSD    9.55   10.00    9.55   10.00
# 34496      1462798800   09  ETHUSD    0.00   12.00    0.00    9.55
#
#             Volume  Year Month          Day      Time
# 0       650.188125  2020    04  16 00:00:00  00:00:00
# ...

# %% [markdown]
# ##### Drop the unnecessary column 'Day' by drop function

# %%
#DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')[source]
df1.drop(labels=None,axis=1,index=None,columns='Day',inplace=True)
df1
# Out:
#        Unix Timestamp Date  Symbol    Open    High     Low   Close  \
# 0       1586995200000   16  ETHUSD  152.94  152.94  150.39  150.39
# 1       1586991600000   15  ETHUSD  155.81  155.81  151.39  152.94
# 2       1586988000000   15  ETHUSD  157.18  157.30  155.32  155.81
# 3       1586984400000   15  ETHUSD  158.04  158.31  157.16  157.18
# 4       1586980800000   15  ETHUSD  157.10  158.10  156.87  158.04
# ...               ...  ...     ...     ...     ...     ...     ...
# 34492      1462813200   09  ETHUSD    9.83    9.83    9.48    9.49
# 34493      1462809600   09  ETHUSD    9.99    9.99    9.79    9.83
# 34494      1462806000   09  ETHUSD   10.00   10.00    9.99    9.99
# 34495      1462802400   09  ETHUSD    9.55   10.00    9.55   10.00
# 34496      1462798800   09  ETHUSD    0.00   12.00    0.00    9.55
#
#             Volume  Year Month      Time
# 0       650.188125  2020    04  00:00:00
# 1      4277.567299  2020    04  23:00:00
# ...

# %%
df2[['Year','Month','Day']] = df2['Date'].str.split('-',expand=True)
df2
# Out:
#          Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0         1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  151.33
# 1         1586995140000  2020-04-15 23:59:00  ETHUSD  152.94  152.94  152.94
# 2         1586995080000  2020-04-15 23:58:00  ETHUSD  153.17  153.17  152.94
# 3         1586995020000  2020-04-15 23:57:00  ETHUSD  152.96  153.20  152.96
# 4         1586994960000  2020-04-15 23:56:00  ETHUSD  153.14  153.14  152.96
# ...                 ...                  ...     ...     ...     ...     ...
# 1984007      1462800960  2016-05-09 13:36:00  ETHUSD   10.00   10.00   10.00
# 1984008      1462800900  2016-05-09 13:35:00  ETHUSD   10.00   10.00   10.00
# 1984009      1462800840  2016-05-09 13:34:00  ETHUSD   10.00   10.00   10.00
# 1984010      1462800780  2016-05-09 13:33:00  ETHUSD   12.00   12.00   10.00
# 1984011      1462800720  2016-05-09 13:32:00  ETHUSD    0.00   12.00    0.00
#
# ...

# %%
df2[['Date','Time']] = df2['Day'].str.split(' ',expand=True)
df2
# Out:
#          Unix Timestamp Date  Symbol    Open    High     Low   Close  \
# 0         1586995200000   16  ETHUSD  152.94  152.94  151.33  151.33
# 1         1586995140000   15  ETHUSD  152.94  152.94  152.94  152.94
# 2         1586995080000   15  ETHUSD  153.17  153.17  152.94  152.94
# 3         1586995020000   15  ETHUSD  152.96  153.20  152.96  153.17
# 4         1586994960000   15  ETHUSD  153.14  153.14  152.96  152.96
# ...                 ...  ...     ...     ...     ...     ...     ...
# 1984007      1462800960   09  ETHUSD   10.00   10.00   10.00   10.00
# 1984008      1462800900   09  ETHUSD   10.00   10.00   10.00   10.00
# 1984009      1462800840   09  ETHUSD   10.00   10.00   10.00   10.00
# 1984010      1462800780   09  ETHUSD   12.00   12.00   10.00   10.00
# 1984011      1462800720   09  ETHUSD    0.00   12.00    0.00   12.00
#
#              Volume  Year Month          Day      Time
# 0        112.724931  2020    04  16 00:00:00  00:00:00
# ...

# %%
df2.drop(labels=None,axis=1,index=None,columns='Day',inplace=True)
df2
# Out:
#          Unix Timestamp Date  Symbol    Open    High     Low   Close  \
# 0         1586995200000   16  ETHUSD  152.94  152.94  151.33  151.33
# 1         1586995140000   15  ETHUSD  152.94  152.94  152.94  152.94
# 2         1586995080000   15  ETHUSD  153.17  153.17  152.94  152.94
# 3         1586995020000   15  ETHUSD  152.96  153.20  152.96  153.17
# 4         1586994960000   15  ETHUSD  153.14  153.14  152.96  152.96
# ...                 ...  ...     ...     ...     ...     ...     ...
# 1984007      1462800960   09  ETHUSD   10.00   10.00   10.00   10.00
# 1984008      1462800900   09  ETHUSD   10.00   10.00   10.00   10.00
# 1984009      1462800840   09  ETHUSD   10.00   10.00   10.00   10.00
# 1984010      1462800780   09  ETHUSD   12.00   12.00   10.00   10.00
# 1984011      1462800720   09  ETHUSD    0.00   12.00    0.00   12.00
#
#              Volume  Year Month      Time
# 0        112.724931  2020    04  00:00:00
# 1          0.000000  2020    04  23:59:00
# ...

# %%
df3[['Year','Month','Day']] = df3['Date'].str.split('-',expand=True)
df3
# Out:
#             Date  Symbol    Open    High     Low   Close  Volume ETH  \
# 0     2020-04-15  ETHUSD  158.61  158.61  158.61  158.61        0.00
# 1     2020-04-14  ETHUSD  156.97  162.15  155.74  158.61    18061.58
# 2     2020-04-13  ETHUSD  158.56  159.51  150.12  156.97    15698.32
# 3     2020-04-12  ETHUSD  158.66  165.37  155.21  158.56    12877.33
# 4     2020-04-11  ETHUSD  158.26  161.49  154.25  158.66    13761.72
# ...          ...     ...     ...     ...     ...     ...         ...
# 1433  2016-05-13  ETHUSD   10.20   11.59   10.20   10.69     1769.71
# 1434  2016-05-12  ETHUSD   10.43   12.00    9.92   10.20     2072.56
# 1435  2016-05-11  ETHUSD    9.68   10.47    9.68   10.43     3052.51
# 1436  2016-05-10  ETHUSD    9.98    9.98    9.36    9.68      672.06
# 1437  2016-05-09  ETHUSD   12.00   12.00    9.36    9.98     1317.90
#
#       Volume USD  Year Month Day
# 0           0.00  2020    04  15
# 1     2872210.44  2020    04  14
# 2     2416728.28  2020    04  13
# ...

# %%
df3.drop(labels=None,axis=1,index=None,columns='Date',inplace=True)
df3
# Out:
#       Symbol    Open    High     Low   Close  Volume ETH  Volume USD  Year  \
# 0     ETHUSD  158.61  158.61  158.61  158.61        0.00        0.00  2020
# 1     ETHUSD  156.97  162.15  155.74  158.61    18061.58  2872210.44  2020
# 2     ETHUSD  158.56  159.51  150.12  156.97    15698.32  2416728.28  2020
# 3     ETHUSD  158.66  165.37  155.21  158.56    12877.33  2082804.05  2020
# 4     ETHUSD  158.26  161.49  154.25  158.66    13761.72  2172914.57  2020
# ...      ...     ...     ...     ...     ...         ...         ...   ...
# 1433  ETHUSD   10.20   11.59   10.20   10.69     1769.71    18923.55  2016
# 1434  ETHUSD   10.43   12.00    9.92   10.20     2072.56    22183.39  2016
# 1435  ETHUSD    9.68   10.47    9.68   10.43     3052.51    30978.11  2016
# 1436  ETHUSD    9.98    9.98    9.36    9.68      672.06     6578.20  2016
# 1437  ETHUSD   12.00   12.00    9.36    9.98     1317.90    12885.06  2016
#
#      Month Day
# 0       04  15
# 1       04  14
# 2       04  13
# ...

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df3['Year'],df3['Volume ETH'])
plt.title('Year Wise ETHEREUM Volume',size=15)
plt.ylabel('volume of Ethereum')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df1['Year'],df1['Volume'])
plt.title('Year Wise ETHEREUM Volume',size=15)
plt.ylabel('volume of Ethereum')
plt.xlabel('Year')
plt.show()

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df2['Year'],df2['Volume'])
plt.title('Year Wise ETHEREUM Volume',size=15)
plt.ylabel('volume of Ethereum')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ##### As we can derived from the above graphs where we plot the volume of Ethereum to Year we can clearly see Year 2017 is the year where the most no volume of Ethereum held.

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df3['Year'],df3['Volume USD'])
plt.title('Year Wise USD Volume',size=20)
plt.ylabel('volume of $')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ##### As we can derived from the above graph where we plot the volume of USD  to Year we can clearly see Year 2018 is the year where the most no volume of USD held.

# %%
df1[df1['Year']=='2020']['Volume'].max()
# Out:
# 38159.43166339

# %%
df1[df1['Year']=='2020']['Volume'].min()
# Out:
# 0.0

# %%
df1[df1['Year']=='2016']['Volume'].max()
# Out:
# 11530.31155

# %%
df1[df1['Year']=='2016']['Volume'].min()
# Out:
# 0.0

# %%
df1[df1['Year']=='2017']['Volume'].max()
# Out:
# 903102.6857

# %%
df1[df1['Year']=='2017']['Volume'].min()
# Out:
# 0.0

# %%
df1[df1['Year']=='2018']['Volume'].max()
# Out:
# 76871.4727841

# %%
df1[df1['Year']=='2018']['Volume'].min()
# Out:
# 0.0

# %%
df1[df1['Year']=='2019']['Volume'].max()
# Out:
# 39822.748276

# %%
df1[df1['Year']=='2019']['Volume'].min()
# Out:
# 0.0

# %% [markdown]
# ##### In dataframe1  on the basis of Volume Year wise max volume is the Highest in  2017  as we see in the dataframe value

# %%
df2[df2['Year']=='2019']['Volume'].max()
# Out:
# 19261.261188

# %%
df2[df2['Year']=='2020']['Volume'].max()
# Out:
# 6505.774141

# %%
df2[df2['Year']=='2018']['Volume'].max()
# Out:
# 10834.477541

# %%
df2[df2['Year']=='2017']['Volume'].max()
# Out:
# 276423.537308

# %%
df2[df2['Year']=='2016']['Volume'].max()
# Out:
# 11108.057755

# %% [markdown]
# ##### In dataframe2  on the basis of Volume Year wise max volume is the Highest in  2017  as we see in the dataframe value

# %%
df3[df3['Year']=='2016']['Volume ETH'].max()
# Out:
# 56219.2

# %%
df3[df3['Year']=='2017']['Volume ETH'].max()
# Out:
# 1827755.14

# %%
df3[df3['Year']=='2018']['Volume ETH'].max()
# Out:
# 238715.97

# %%
df3[df3['Year']=='2019']['Volume ETH'].max()
# Out:
# 108006.29

# %%
df3[df3['Year']=='2020']['Volume ETH'].max()
# Out:
# 206706.03

# %% [markdown]
# ##### In dataframe3  on the basis of Volume OF Ethereum Year wise max volume Ethereum is the Highest in  2017  as we see in the dataframe value

# %%
df3[df3['Year']=='2020']['Volume USD'].max()
# Out:
# 29236156.49

# %%
df3[df3['Year']=='2019']['Volume USD'].max()
# Out:
# 26728002.47

# %%
df3[df3['Year']=='2018']['Volume USD'].max()
# Out:
# 222119304.91

# %%
df3[df3['Year']=='2017']['Volume USD'].max()
# Out:
# 191739093.28

# %%
df3[df3['Year']=='2016']['Volume USD'].max()
# Out:
# 936997.53

# %% [markdown]
# ##### In dataframe3  on the basis of Volume OF USD Year wise max volume USD is the Highest in  2018  as we see in the dataframe value

# %%
df2[(df2['Month']=='04') & (df2['Year']=='2020')]['Volume'].max()
# Out:
# 4215.162585

# %%
df2[(df2['Month']=='04') & (df2['Year']=='2019')]['Volume'].max()
# Out:
# 8163.920965

# %%
df2[(df2['Month']=='04') & (df2['Year']=='2018')]['Volume'].max()
# Out:
# 4393.72940315

# %%
df2[(df2['Month']=='04') & (df2['Year']=='2017')]['Volume'].max()
# Out:
# 5346.665874

# %%
df2[(df2['Month']=='04') & (df2['Year']=='2016')]['Volume'].max()
# Out:
# nan

# %% [markdown]
# #### INSIGHTS:-
# ##### April Month Volume of Ethereum based on each year based Analysis and april 2019  has the highest volume rate of Ethereum

# %% [markdown]
# ### Creating a Pivot  for month wise per Year Volume check of Ethereum of DATAFRAME1

# %%
#Syntax : dataframe.pivot(self, index=None, columns=None, values=None, aggfunc)
month_wise_volume_per_year_df1=df1.pivot_table(index=['Month'],values=['Volume'],columns=['Year'],aggfunc='max')

# %%
month_wise_volume_per_year_df1.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_4a516_row0_col0, #T_4a516_row1_col0, #T_4a516_row2_col0, #T_4a516_row3_col0, #T_4a516_row4_col4, #T_4a516_row5_col4, #T_4a516_row6_col4, #T_4a516_row7_col4, #T_4a516_row8_col4, #T_4a516_row9_col4, #T_4a516_row10_col4, #T_4a516_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4a516_row0_col1, #T_4a516_row7_col1 {
#   background-color: #068266;
#   color: #f1f1f1;
# }
# #T_4a516_row0_col2 {
#   background-color: #43a166;
#   color: #f1f1f1;
# }
# #T_4a516_row0_col3, #T_4a516_row1_col1, #T_4a516_row2_col4, #T_4a516_row5_col0, #T_4a516_row11_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4a516_row0_col4 {
#   background-color: #2e9666;
#   color: #f1f1f1;
# }
# #T_4a516_row1_col2, #T_4a516_row8_col2 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_4a516_row1_col3 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_4a516_row1_col4 {
#   background-color: #359a66;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ##### INSIGHTS:- VOLUME OF ETHEREUM  ON DATAFRAME_1 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - DECEMBER,    LOWEST ON 2016 - SEPTEMBER
# HIGHEST ON 2017 - FEBRUARY,    LOWEST ON 2017 - APRIL
# HIGHEST ON 2018 - DECEMBER,    LOWEST ON 2018 - JULY
# HIGHEST ON 2019 - JANUARY,     LOWEST ON 2019 - DECEMBER
# HIGHEST ON 2020 - MARCH,       LOWEST ON 2020 - APRIL

# %% [markdown]
# ### Creating a Pivot  for month wise per Year Volume check of Ethereum of DATAFRAME 2

# %%
month_wise_volume_per_year_df2=df2.pivot_table(index=['Month'],values=['Volume'],columns=['Year'],aggfunc='max')

# %%
month_wise_volume_per_year_df2.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_1c148_row0_col0, #T_1c148_row1_col0, #T_1c148_row2_col0, #T_1c148_row3_col0, #T_1c148_row4_col4, #T_1c148_row5_col4, #T_1c148_row6_col4, #T_1c148_row7_col4, #T_1c148_row8_col4, #T_1c148_row9_col4, #T_1c148_row10_col4, #T_1c148_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1c148_row0_col1 {
#   background-color: #1b8d66;
#   color: #f1f1f1;
# }
# #T_1c148_row0_col2 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_1c148_row0_col3 {
#   background-color: #53a966;
#   color: #f1f1f1;
# }
# #T_1c148_row0_col4 {
#   background-color: #219066;
#   color: #f1f1f1;
# }
# #T_1c148_row1_col1 {
#   background-color: #76bb66;
#   color: #f1f1f1;
# }
# #T_1c148_row1_col2 {
#   background-color: #69b466;
#   color: #f1f1f1;
# }
# #T_1c148_row1_col3 {
#   background-color: #72b866;
#   color: #f1f1f1;
# }
# #T_1c148_row1_col4, #T_1c148_row2_col1, #T_1c148_row5_col0, #T_1c148_row5_col3, #T_1c148_row8_col2 {
# ...

# %% [markdown]
# ##### INSIGHTS:- VOLUME OF ETHEREUM  ON DATAFRAME_2 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - NOVEMBER,    LOWEST ON 2016 - JUNE
# HIGHEST ON 2017 - MARCH,       LOWEST ON 2017 - DECEMBER
# HIGHEST ON 2018 - SEPTEMBER,   LOWEST ON 2018 - JULY
# HIGHEST ON 2019 - JUNE,        LOWEST ON 2019 - JULY
# HIGHEST ON 2020 - FEBRUARY,    LOWEST ON 2020 - APRIL

# %% [markdown]
# ### Creating a Pivot  for month wise per Year Volume check of Ethereum of DATAFRAME 3

# %%
month_wise_per_year_volume_df3=df3.pivot_table(index=['Month'],values=['Volume ETH'],columns=['Year'],aggfunc='max')

# %%
month_wise_per_year_volume_df3.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_4e51a_row0_col0, #T_4e51a_row1_col0, #T_4e51a_row2_col0, #T_4e51a_row3_col0, #T_4e51a_row4_col4, #T_4e51a_row5_col4, #T_4e51a_row6_col4, #T_4e51a_row7_col4, #T_4e51a_row8_col4, #T_4e51a_row9_col4, #T_4e51a_row10_col4, #T_4e51a_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4e51a_row0_col1, #T_4e51a_row0_col4, #T_4e51a_row6_col2, #T_4e51a_row10_col0, #T_4e51a_row11_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_4e51a_row0_col2, #T_4e51a_row1_col1, #T_4e51a_row2_col4, #T_4e51a_row3_col3, #T_4e51a_row5_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4e51a_row0_col3 {
#   background-color: #93c966;
#   color: #000000;
# }
# #T_4e51a_row1_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_4e51a_row1_col3 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_4e51a_row1_col4 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_4e51a_row2_col1 {
# ...

# %% [markdown]
# ##### INSIGHTS:- VOLUME OF ETHEREUM  ON DATAFRAME_3 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - NOVEMBER
# HIGHEST ON 2017 - FEBRUARY,   LOWEST ON 2017 - APRIL
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - JULY
# HIGHEST ON 2019 - APRIL,      LOWEST ON 2019 - DECEMBER
# HIGHEST ON 2020 - MARCH,      LOWEST ON 2020 - JANUARY

# %%
month_wise_per_year_volumeUSD_df3=df3.pivot_table(index=['Month'],values=['Volume USD'],columns=['Year'],aggfunc='max')

# %%
month_wise_per_year_volumeUSD_df3.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_89d6b_row0_col0, #T_89d6b_row1_col0, #T_89d6b_row2_col0, #T_89d6b_row3_col0, #T_89d6b_row4_col4, #T_89d6b_row5_col4, #T_89d6b_row6_col4, #T_89d6b_row7_col4, #T_89d6b_row8_col4, #T_89d6b_row9_col4, #T_89d6b_row10_col4, #T_89d6b_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_89d6b_row0_col1, #T_89d6b_row0_col4, #T_89d6b_row10_col0, #T_89d6b_row11_col2, #T_89d6b_row11_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_89d6b_row0_col2, #T_89d6b_row2_col4, #T_89d6b_row4_col3, #T_89d6b_row5_col0, #T_89d6b_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_89d6b_row0_col3 {
#   background-color: #379b66;
#   color: #f1f1f1;
# }
# #T_89d6b_row1_col1 {
#   background-color: #1e8e66;
#   color: #f1f1f1;
# }
# #T_89d6b_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_89d6b_row1_col3 {
#   background-color: #71b866;
#   color: #f1f1f1;
# }
# #T_89d6b_row1_col4 {
# ...

# %% [markdown]
# ##### INSIGHTS:- VOLUME OF ETHEREUM  ON DATAFRAME_3 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - NOVEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - APRIL
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - MAY,        LOWEST ON 2019 - DECEMBER
# HIGHEST ON 2020 - MARCH,      LOWEST ON 2020 - JANUARY

# %% [markdown]
#    ## Creating Pivot Month Wise Per Year Highest for Open Area for ETHEREUM

# %%
month_wise_OPEN_per_year_df1=df1.pivot_table(index=['Month'],values=['Open'],columns=['Year'],aggfunc='max')

# %%
month_wise_OPEN_per_year_df1.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_89548_row0_col0, #T_89548_row1_col0, #T_89548_row2_col0, #T_89548_row3_col0, #T_89548_row4_col4, #T_89548_row5_col4, #T_89548_row6_col4, #T_89548_row7_col4, #T_89548_row8_col4, #T_89548_row9_col4, #T_89548_row10_col4, #T_89548_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_89548_row0_col1, #T_89548_row2_col3, #T_89548_row3_col4, #T_89548_row11_col0, #T_89548_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_89548_row0_col2, #T_89548_row1_col4, #T_89548_row5_col0, #T_89548_row5_col3, #T_89548_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_89548_row0_col3 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_89548_row0_col4 {
#   background-color: #1a8c66;
#   color: #f1f1f1;
# }
# #T_89548_row1_col1 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_89548_row1_col2 {
#   background-color: #c8e366;
#   color: #000000;
# }
# #T_89548_row1_col3 {
# ...

# %% [markdown]
# ##### INSIGHTS:- OPEN SECTION OF ETHEREUM  ON DATAFRAME_1 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - DECEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - JANUARY
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - JUNE,       LOWEST ON 2019 - MARCH
# HIGHEST ON 2020 - FEBRUARY,   LOWEST ON 2020 - APRIL

# %%
month_wise_OPEN_per_year_df2=df2.pivot_table(index=['Month'],values=['Open'],columns=['Year'],aggfunc='max')

# %%
month_wise_OPEN_per_year_df2.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_43742_row0_col0, #T_43742_row1_col0, #T_43742_row2_col0, #T_43742_row3_col0, #T_43742_row4_col4, #T_43742_row5_col4, #T_43742_row6_col4, #T_43742_row7_col4, #T_43742_row8_col4, #T_43742_row9_col4, #T_43742_row10_col4, #T_43742_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_43742_row0_col1, #T_43742_row2_col3, #T_43742_row3_col4, #T_43742_row11_col0, #T_43742_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_43742_row0_col2, #T_43742_row1_col4, #T_43742_row5_col0, #T_43742_row5_col3, #T_43742_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_43742_row0_col3 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_43742_row0_col4, #T_43742_row1_col3 {
#   background-color: #178b66;
#   color: #f1f1f1;
# }
# #T_43742_row1_col1 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_43742_row1_col2 {
#   background-color: #c8e366;
#   color: #000000;
# }
# ...

# %% [markdown]
# ##### INSIGHTS:- OPEN SECTION OF ETHEREUM  ON DATAFRAME_2 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - DECEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - JANUARY
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - JUNE,       LOWEST ON 2019 - MARCH
# HIGHEST ON 2020 - FEBRUARY,   LOWEST ON 2020 - APRIL

# %%
month_wise_OPEN_per_year_df3=df3.pivot_table(index=['Month'],values=['Open'],columns=['Year'],aggfunc='max')

# %%
month_wise_OPEN_per_year_df3.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_31a6c_row0_col0, #T_31a6c_row1_col0, #T_31a6c_row2_col0, #T_31a6c_row3_col0, #T_31a6c_row4_col4, #T_31a6c_row5_col4, #T_31a6c_row6_col4, #T_31a6c_row7_col4, #T_31a6c_row8_col4, #T_31a6c_row9_col4, #T_31a6c_row10_col4, #T_31a6c_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_31a6c_row0_col1, #T_31a6c_row2_col3, #T_31a6c_row3_col4, #T_31a6c_row11_col0, #T_31a6c_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_31a6c_row0_col2, #T_31a6c_row1_col4, #T_31a6c_row5_col0, #T_31a6c_row5_col3, #T_31a6c_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_31a6c_row0_col3 {
#   background-color: #128866;
#   color: #f1f1f1;
# }
# #T_31a6c_row0_col4 {
#   background-color: #188c66;
#   color: #f1f1f1;
# }
# #T_31a6c_row1_col1 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_31a6c_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_31a6c_row1_col3 {
# ...

# %% [markdown]
# ##### INSIGHTS:- OPEN SECTION OF ETHEREUM  ON DATAFRAME_3 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - NOVEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - APRIL
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - JUNE,       LOWEST ON 2019 - DECEMBER
# HIGHEST ON 2020 - FEBRUARY,   LOWEST ON 2020 - APRIL

# %% [markdown]
#    ## Creating Pivot Month Wise Per Year Highest for High Area for ETHEREUM

# %%
high_df1=df1.pivot_table(index=['Month'],values=['High'],columns=['Year'],aggfunc='max')

# %%
high_df1.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_e9269_row0_col0, #T_e9269_row1_col0, #T_e9269_row2_col0, #T_e9269_row3_col0, #T_e9269_row4_col4, #T_e9269_row5_col4, #T_e9269_row6_col4, #T_e9269_row7_col4, #T_e9269_row8_col4, #T_e9269_row9_col4, #T_e9269_row10_col4, #T_e9269_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e9269_row0_col1, #T_e9269_row2_col3, #T_e9269_row3_col4, #T_e9269_row11_col0, #T_e9269_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_e9269_row0_col2, #T_e9269_row1_col4, #T_e9269_row5_col0, #T_e9269_row5_col3, #T_e9269_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e9269_row0_col3 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_e9269_row0_col4, #T_e9269_row1_col3 {
#   background-color: #178b66;
#   color: #f1f1f1;
# }
# #T_e9269_row1_col1 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_e9269_row1_col2 {
#   background-color: #c8e366;
#   color: #000000;
# }
# ...

# %% [markdown]
# ##### INSIGHTS:- OPEN SECTION OF ETHEREUM  ON DATAFRAME_1 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - DECEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - JANUARY
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - JUNE,       LOWEST ON 2019 - MARCH
# HIGHEST ON 2020 - FEBRUARY,   LOWEST ON 2020 - APRIL

# %%
high_df2=df2.pivot_table(index=['Month'],values=['High'],columns=['Year'],aggfunc='max')

# %%
high_df2.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_fea27_row0_col0, #T_fea27_row1_col0, #T_fea27_row2_col0, #T_fea27_row3_col0, #T_fea27_row4_col4, #T_fea27_row5_col4, #T_fea27_row6_col4, #T_fea27_row7_col4, #T_fea27_row8_col4, #T_fea27_row9_col4, #T_fea27_row10_col4, #T_fea27_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_fea27_row0_col1, #T_fea27_row2_col3, #T_fea27_row3_col4, #T_fea27_row11_col0, #T_fea27_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_fea27_row0_col2, #T_fea27_row1_col4, #T_fea27_row5_col0, #T_fea27_row5_col3, #T_fea27_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fea27_row0_col3 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_fea27_row0_col4, #T_fea27_row1_col3 {
#   background-color: #178b66;
#   color: #f1f1f1;
# }
# #T_fea27_row1_col1 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_fea27_row1_col2 {
#   background-color: #c8e366;
#   color: #000000;
# }
# ...

# %% [markdown]
# ##### INSIGHTS:- OPEN SECTION OF ETHEREUM  ON DATAFRAME_2 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - DECEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - JANUARY
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - JUNE,       LOWEST ON 2019 - MARCH
# HIGHEST ON 2020 - FEBRUARY,   LOWEST ON 2020 - APRIL

# %%
high_df3=df3.pivot_table(index=['Month'],values=['High'],columns=['Year'],aggfunc='max')

# %%
high_df3.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_89fbe_row0_col0, #T_89fbe_row1_col0, #T_89fbe_row2_col0, #T_89fbe_row3_col0, #T_89fbe_row4_col4, #T_89fbe_row5_col4, #T_89fbe_row6_col4, #T_89fbe_row7_col4, #T_89fbe_row8_col4, #T_89fbe_row9_col4, #T_89fbe_row10_col4, #T_89fbe_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_89fbe_row0_col1, #T_89fbe_row2_col3, #T_89fbe_row3_col4, #T_89fbe_row11_col0, #T_89fbe_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_89fbe_row0_col2, #T_89fbe_row1_col4, #T_89fbe_row5_col0, #T_89fbe_row5_col3, #T_89fbe_row11_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_89fbe_row0_col3 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_89fbe_row0_col4, #T_89fbe_row1_col3 {
#   background-color: #178b66;
#   color: #f1f1f1;
# }
# #T_89fbe_row1_col1 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_89fbe_row1_col2 {
#   background-color: #c8e366;
#   color: #000000;
# }
# ...

# %% [markdown]
# ##### INSIGHTS:- OPEN SECTION OF ETHEREUM  ON DATAFRAME_3 (HIGHEST MARKED BY YELLOW)
# HIGHEST ON 2016 - JUNE,       LOWEST ON 2016 - DECEMBER
# HIGHEST ON 2017 - DECEMBER,   LOWEST ON 2017 - JANUARY
# HIGHEST ON 2018 - JANUARY,    LOWEST ON 2018 - DECEMBER
# HIGHEST ON 2019 - JUNE,       LOWEST ON 2019 - MARCH
# HIGHEST ON 2020 - FEBRUARY,   LOWEST ON 2020 - APRIL

# %%
plt.figure(figsize=(10,5))
plt.plot(df1[(df1['Year']=='2020')&(df1['Volume'])]['High'],label=2020)
plt.plot(df1[(df1['Year']=='2019')&(df1['Volume'])]['High'],label=2019)
plt.plot(df1[(df1['Year']=='2018')&(df1['Volume'])]['High'],label=2018)
plt.plot(df1[(df1['Year']=='2017')&(df1['Volume'])]['High'],label=2017)
plt.plot(df1[(df1['Year']=='2016')&(df1['Volume'])]['High'],label=2016)
plt.title('year wise high area ')
plt.xlabel('Volume')
plt.ylabel('High')
plt.legend(loc='best')

# %%
plt.figure(figsize=(10,5))
plt.plot(df1[(df1['Year']=='2020')&(df1['Volume'])]['Open'],label=2020)
plt.plot(df1[(df1['Year']=='2019')&(df1['Volume'])]['Open'],label=2019)
plt.plot(df1[(df1['Year']=='2018')&(df1['Volume'])]['Open'],label=2018)
plt.plot(df1[(df1['Year']=='2017')&(df1['Volume'])]['Open'],label=2017)
plt.plot(df1[(df1['Year']=='2016')&(df1['Volume'])]['Open'],label=2016)
plt.title('year wise open area ')
plt.xlabel('Open')
plt.ylabel('volume')
plt.legend(loc='best')

# %%
plt.figure(figsize=(10,5))
plt.plot(df1[(df1['Year']=='2020')&(df1['Volume'])]['Low'],label=2020)
plt.plot(df1[(df1['Year']=='2019')&(df1['Volume'])]['Low'],label=2019)
plt.plot(df1[(df1['Year']=='2018')&(df1['Volume'])]['Low'],label=2018)
plt.plot(df1[(df1['Year']=='2017')&(df1['Volume'])]['Low'],label=2017)
plt.plot(df1[(df1['Year']=='2016')&(df1['Volume'])]['Low'],label=2016)
plt.title('year wise low area ')
plt.xlabel('Low')
plt.ylabel('volume')
plt.legend(loc='best')

# %% [markdown]
# ### Here we can clearly see all 3 cases 2018 has the highest peak and 2020 is the lowest dip
